# %%
import pandas as pd

# %%
file1 = pd.read_csv("file1.csv")
file2 = pd.read_csv("file2.csv")
file3 = pd.read_csv("file3.csv")

# %%
file1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
file2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
file3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
print(file1.columns)
print(file2.columns)
print(file3.columns)
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
file1.columns=file1.columns.str.lower()
file2.columns=file2.columns.str.lower()
file3.columns=file3.columns.str.lower()

# %%
print(file1.columns)
print(file2.columns)
print(file3.columns)
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'vehicle class', 'total claim amount'],
#       dtype='object')
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'total claim amount', 'policy type', 'vehicle class'],
#       dtype='object')
# Index(['customer', 'state', 'customer lifetime value', 'education', 'gender',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'total claim amount', 'vehicle class'],
#       dtype='object')

# %%
file2.reindex(columns=['customer', 'st', 'gender', 'education', 'customer lifetime value', 'income', 'monthly premium auto', 'number of open complaints', 'policy type','vehicle class','total claim amount'])
# Out:
#     customer          st gender education customer lifetime value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly premium auto number of open complaints     policy type  \
# ...

# %%
file3 = file3.rename(columns={'state':'st'})

# %%
file3.reindex(columns=['customer', 'st', 'gender', 'education', 'customer lifetime value', 'income', 'monthly premium auto', 'number of open complaints', 'policy type','vehicle class','total claim amount'])
# Out:
#      customer          st gender             education  \
# 0     SA25987  Washington      M  High School or Below
# 1     TB86706     Arizona      M                Master
# 2     ZL73902      Nevada      F              Bachelor
# 3     KX23516  California      F  High School or Below
# 4     FN77294  California      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       customer lifetime value  income  monthly premium auto  \
# 0                 3479.137523       0                   104
# 1                 2502.637401       0                    66
# 2                 3265.156348   25820                    82
# ...

# %%
data=pd.concat([file1,file2,file3], axis=0)
data
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
data.dtypes
# Out:
# customer                      object
# st                            object
# gender                        object
# education                     object
# customer lifetime value       object
# income                       float64
# monthly premium auto         float64
# number of open complaints     object
# policy type                   object
# vehicle class                 object
# total claim amount           float64
# dtype: object

# %%
data.isna().sum()
# Out:
# customer                     2937
# st                           2937
# gender                       3059
# education                    2937
# customer lifetime value      2944
# income                       2937
# monthly premium auto         2937
# number of open complaints    2937
# policy type                  2937
# vehicle class                2937
# total claim amount           2937
# dtype: int64

# %%
nulls_p = (data.isna().sum()/len(data))*100
nulls_p = nulls_p.reset_index()
nulls_p.columns=["Columna", "Porcentaje"]
nulls_p
# Out:
#                       Columna  Porcentaje
# 0                    customer   24.324996
# 1                          st   24.324996
# 2                      gender   25.335432
# 3                   education   24.324996
# 4     customer lifetime value   24.382972
# 5                      income   24.324996
# 6        monthly premium auto   24.324996
# 7   number of open complaints   24.324996
# 8                 policy type   24.324996
# 9               vehicle class   24.324996
# 10         total claim amount   24.324996

# %%
data = data.dropna()

# %%
data = data.sort_index()

# %%
data = data.drop(['education', 'number of open complaints'], axis=1)
data
# Out:
#      customer          st gender customer lifetime value   income  \
# 0     GS98873     Arizona      F              323912.47%  16061.0
# 0     SA25987  Washington      M             3479.137523      0.0
# 1     TB86706     Arizona      M             2502.637401      0.0
# 1     CW49887  California      F              462680.11%  79487.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M             23405.98798  71941.0
# 7066  PK87824  California      F             3096.511217  21604.0
# 7067  TD14365  California      M             8163.890428      0.0
# 7068  UP19263  California      M             7524.442436  21941.0
# 7069  Y167826  California      M             2611.836866      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                     88.0   Personal Auto  Four-Door Car          633.600000
# ...

# %%
data["customer lifetime value"] = data["customer lifetime value"].replace({'%':''}, regex=True)
data
# Out:
#      customer          st gender customer lifetime value   income  \
# 0     GS98873     Arizona      F               323912.47  16061.0
# 0     SA25987  Washington      M             3479.137523      0.0
# 1     TB86706     Arizona      M             2502.637401      0.0
# 1     CW49887  California      F               462680.11  79487.0
# 1     QZ44356     Arizona      F               697953.59      0.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M             23405.98798  71941.0
# 7066  PK87824  California      F             3096.511217  21604.0
# 7067  TD14365  California      M             8163.890428      0.0
# 7068  UP19263  California      M             7524.442436  21941.0
# 7069  Y167826  California      M             2611.836866      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                     88.0   Personal Auto  Four-Door Car          633.600000
# ...

# %%
pd.to_numeric(data["customer lifetime value"], errors="coerce")
# Out:
# 0       323912.470000
# 0         3479.137523
# 1         2502.637401
# 1       462680.110000
# 1       697953.590000
#             ...
# 7065     23405.987980
# 7066      3096.511217
# 7067      8163.890428
# 7068      7524.442436
# 7069      2611.836866
# Name: customer lifetime value, Length: 9010, dtype: float64

# %%
data["customer lifetime value"] = (data["customer lifetime value"])*100

# %%
data
# Out:
#      customer          st gender  \
# 0     GS98873     Arizona      F
# 0     SA25987  Washington      M
# 1     TB86706     Arizona      M
# 1     CW49887  California      F
# 1     QZ44356     Arizona      F
# ...       ...         ...    ...
# 7065  LA72316  California      M
# 7066  PK87824  California      F
# 7067  TD14365  California      M
# 7068  UP19263  California      M
# 7069  Y167826  California      M
#
#                                 customer lifetime value   income  \
# 0     323912.47323912.47323912.47323912.47323912.473...  16061.0
# 0                                           347913.7523      0.0
# 1                                           250263.7401      0.0
# 1     462680.11462680.11462680.11462680.11462680.114...  79487.0
# 1     697953.59697953.59697953.59697953.59697953.596...      0.0
# ...                                                 ...      ...
# 7065                                        2340598.798  71941.0
# ...

# %%
duplicados = data.duplicated()

# %%
duplicados
# Out:
# 0       False
# 0       False
# 1       False
# 1       False
# 1       False
#         ...
# 7065    False
# 7066    False
# 7067    False
# 7068    False
# 7069    False
# Length: 9010, dtype: bool

# %%
num_duplicados = duplicados.sum()
print(f'Hay {num_duplicados} filas duplicadas')
# Out:
# Hay 3 filas duplicadas

# %%
data = data.drop_duplicates()
data
# Out:
#      customer          st gender  \
# 0     GS98873     Arizona      F
# 0     SA25987  Washington      M
# 1     TB86706     Arizona      M
# 1     CW49887  California      F
# 1     QZ44356     Arizona      F
# ...       ...         ...    ...
# 7065  LA72316  California      M
# 7066  PK87824  California      F
# 7067  TD14365  California      M
# 7068  UP19263  California      M
# 7069  Y167826  California      M
#
#                                 customer lifetime value   income  \
# 0     323912.47323912.47323912.47323912.47323912.473...  16061.0
# 0                                           347913.7523      0.0
# 1                                           250263.7401      0.0
# 1     462680.11462680.11462680.11462680.11462680.114...  79487.0
# 1     697953.59697953.59697953.59697953.59697953.596...      0.0
# ...                                                 ...      ...
# 7065                                        2340598.798  71941.0
# ...

# %%
duplicados = data.duplicated()
num_duplicados = duplicados.sum()
print(f'Ahora hay {num_duplicados} filas duplicadas')
# Out:
# Ahora hay 0 filas duplicadas

# %%
income_low = data[(data["income"] <=0)]

# %%
income_low
# Out:
#      customer          st gender  \
# 0     SA25987  Washington      M
# 1     TB86706     Arizona      M
# 1     QZ44356     Arizona      F
# 3     KX23516  California      F
# 3     WW63253  California      M
# ...       ...         ...    ...
# 7059  WZ45103  California      F
# 7061  RX91025  California      M
# 7062  AC13887  California      M
# 7067  TD14365  California      M
# 7069  Y167826  California      M
#
#                                 customer lifetime value  income  \
# 0                                           347913.7523     0.0
# 1                                           250263.7401     0.0
# 1     697953.59697953.59697953.59697953.59697953.596...     0.0
# 3                                           445584.3406     0.0
# 3     764586.18764586.18764586.18764586.18764586.187...     0.0
# ...                                                 ...     ...
# 7059                                        567805.0167     0.0
# ...
