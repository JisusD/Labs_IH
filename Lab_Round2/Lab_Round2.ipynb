# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("marketing_customer_analysis.csv")

# %%
data
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
data.columns=data.columns.str.lower()
print(data.columns)
# Out:
# Index(['unnamed: 0', 'customer', 'state', 'customer lifetime value',
#        'response', 'coverage', 'education', 'effective to date',
#        'employmentstatus', 'gender', 'income', 'location code',
#        'marital status', 'monthly premium auto', 'months since last claim',
#        'months since policy inception', 'number of open complaints',
#        'number of policies', 'policy type', 'policy', 'renew offer type',
#        'sales channel', 'total claim amount', 'vehicle class', 'vehicle size',
#        'vehicle type'],
#       dtype='object')

# %%
data.dtypes
# Out:
# unnamed: 0                         int64
# customer                          object
# state                             object
# customer lifetime value          float64
# response                          object
# coverage                          object
# education                         object
# effective to date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location code                     object
# marital status                    object
# monthly premium auto               int64
# months since last claim          float64
# months since policy inception      int64
# number of open complaints        float64
# number of policies                 int64
# policy type                       object
# policy                            object
# renew offer type                  object
# sales channel                     object
# total claim amount               float64
# ...

# %%
nulls_p = (data.isna().sum()/len(data))*100
nulls_p = nulls_p.reset_index()
nulls_p.columns=["Columna", "Porcentaje"]
nulls_p
# Out:
#                           Columna  Porcentaje
# 0                      unnamed: 0    0.000000
# 1                        customer    0.000000
# 2                           state    5.783685
# 3         customer lifetime value    0.000000
# 4                        response    5.783685
# 5                        coverage    0.000000
# 6                       education    0.000000
# 7               effective to date    0.000000
# 8                employmentstatus    0.000000
# 9                          gender    0.000000
# 10                         income    0.000000
# 11                  location code    0.000000
# 12                 marital status    0.000000
# 13           monthly premium auto    0.000000
# 14        months since last claim    5.802016
# 15  months since policy inception    0.000000
# 16      number of open complaints    5.802016
# 17             number of policies    0.000000
# 18                    policy type    0.000000
# ...

# %%
data = data.drop(["unnamed: 0"], axis=1)

# %%
data = data.drop(["vehicle type"], axis=1)

# %%
data["state"].unique()
# Out:
# array(['Arizona', 'California', 'Washington', 'Oregon', nan, 'Nevada'],
#       dtype=object)

# %%
data[data['state'].isnull()]
# Out:
#       customer state  customer lifetime value response  coverage  \
# 5      HO81102   NaN              4745.181764      NaN     Basic
# 11     GE63585   NaN              2420.711888      NaN     Basic
# 58     BR69566   NaN             14019.833140      NaN     Basic
# 62     UF44021   NaN              2108.493744      NaN     Basic
# 126    TE60343   NaN              4716.264294      NaN     Basic
# ...        ...   ...                      ...      ...       ...
# 10837  IJ40048   NaN              4978.950257      NaN     Basic
# 10849  SO38188   NaN              5308.617246      NaN  Extended
# 10874  PD52748   NaN             10036.536340      NaN  Extended
# 10894  EX63393   NaN              6314.492009      NaN  Extended
# 10909  IV32877   NaN              6857.519928      NaN     Basic
#
#                   education effective to date employmentstatus gender  income  \
# 5      High School or Below           2/14/11         Employed      M   50549
# ...

# %%
data[data['months since last claim'].isnull()]
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 4      QA50777      Oregon              9025.067525       No   Premium
# 23     NQ71171  California              5107.071054       No     Basic
# 51     FT56968     Arizona              2590.096027       No     Basic
# 59     EP83939     Arizona              5575.751228       No     Basic
# 67     KR35099  Washington              7507.455372      Yes     Basic
# ...        ...         ...                      ...      ...       ...
# 10801  AP56340  Washington              5384.671725       No     Basic
# 10816  AW71157  California              5531.723723       No     Basic
# 10833  OQ99704  Washington              3981.775889       No     Basic
# 10834  FU99476  Washington              6770.306834       No  Extended
# 10905  FE99816      Nevada             15563.369440       No   Premium
#
#                   education effective to date employmentstatus gender  income  \
# ...

# %%
data[data['vehicle class'].isnull()]
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 87     ZH92587      Oregon              8126.766397       No     Basic
# 88     CJ51511     Arizona             13466.920710      Yes     Basic
# 89     ME37450     Arizona              5210.348372       No     Basic
# 97     CA22248      Oregon              2505.420430       No     Basic
# 148    HB24005  California              2347.048112       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10852  KZ80424  Washington              8382.478392      Yes     Basic
# 10860  GA79817     Arizona              2369.111588       No     Basic
# 10879  FK95213  California             18611.453560       No  Extended
# 10883  FD64348      Oregon             22563.618380       No     Basic
# 10890  VQ78876      Oregon              4660.399573       No     Basic
#
#                   education effective to date employmentstatus gender  income  \
# ...

# %%
data = data.dropna()

# %%
data
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 6      IW72280  California              5035.035257       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10903  SU71163     Arizona              2771.663013       No     Basic
# 10904  QI63521      Nevada             19228.463620       No     Basic
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
#
#                   education effective to date employmentstatus gender  income  \
# ...

# %%
nulls_p = (data.isna().sum()/len(data))*100
nulls_p = nulls_p.reset_index()
nulls_p.columns=["Columna", "Porcentaje"]
nulls_p
# Out:
#                           Columna  Porcentaje
# 0                        customer         0.0
# 1                           state         0.0
# 2         customer lifetime value         0.0
# 3                        response         0.0
# 4                        coverage         0.0
# 5                       education         0.0
# 6               effective to date         0.0
# 7                employmentstatus         0.0
# 8                          gender         0.0
# 9                          income         0.0
# 10                  location code         0.0
# 11                 marital status         0.0
# 12           monthly premium auto         0.0
# 13        months since last claim         0.0
# 14  months since policy inception         0.0
# 15      number of open complaints         0.0
# 16             number of policies         0.0
# 17                    policy type         0.0
# 18                         policy         0.0
# ...

# %%
data["effective to date"] = pd.to_datetime(data["effective to date"],errors="coerce")

# %%
data["month"] = data["effective to date"].dt.month

# %%
data
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 6      IW72280  California              5035.035257       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10903  SU71163     Arizona              2771.663013       No     Basic
# 10904  QI63521      Nevada             19228.463620       No     Basic
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
#
#                   education effective to date employmentstatus gender  income  \
# ...

# %%
data["month"].unique()
# Out:
# array([2, 1], dtype=int64)

# %%
income_low = data[(data["month"] <= 3)]
income_low
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 6      IW72280  California              5035.035257       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10903  SU71163     Arizona              2771.663013       No     Basic
# 10904  QI63521      Nevada             19228.463620       No     Basic
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
#
#                   education effective to date employmentstatus gender  income  \
# ...
